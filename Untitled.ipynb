# %%
# %matplotlib inline
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
plot_01=np.loadtxt('plots.m64.01000')
plot_02=np.loadtxt('plots.m64.02000')
plot_03=np.loadtxt('plots.m64.03000')
plot_04=np.loadtxt('plots.m64.04000')
plot_05=np.loadtxt('plots.m64.05000')
plot_06=np.loadtxt('plots.m64.06000')
plot_07=np.loadtxt('plots.m64.07000')
plot_08=np.loadtxt('plots.m64.08000')
plot_09=np.loadtxt('plots.m64.09000')
plot_10=np.loadtxt('plots.m64.10000')

# %%
i=66

plts_01NEW=np.reshape(plot_01,(i,i),order='C')
plts_02NEW=np.reshape(plot_02,(i,i),order='C')
plts_03NEW=np.reshape(plot_03,(i,i),order='C')
plts_04NEW=np.reshape(plot_04,(i,i),order='C')
plts_05NEW=np.reshape(plot_05,(i,i),order='C')
plts_06NEW=np.reshape(plot_06,(i,i),order='C')
plts_07NEW=np.reshape(plot_07,(i,i),order='C')
plts_08NEW=np.reshape(plot_08,(i,i),order='C')
plts_09NEW=np.reshape(plot_09,(i,i),order='C')
plts_10NEW=np.reshape(plot_10,(i,i),order='C')

# %%
plt.rcParams['figure.figsize']=(15,10)

plt.subplot(241)
plt.pcolor(plts_01NEW)
plt.clim(.1,.9)
plt.title('1000')

plt.subplot(242)
plt.yticks([])
plt.pcolor(plts_02NEW)
plt.clim(.1,.9)
plt.title('2000')

plt.subplot(243)
plt.yticks([])
plt.pcolor(plts_03NEW)
plt.clim(.1,.9)
plt.title('3000')

plt.subplot(244)
plt.yticks([])
plt.pcolor(plts_04NEW)
plt.clim(.1,.9)
plt.title('4000')
plt.colorbar()

plt.subplot(245)
plt.pcolor(plts_05NEW)
plt.clim(.1,.9)
plt.title('5000')

plt.subplot(246)
plt.yticks([])
plt.pcolor(plts_06NEW)
plt.clim(.1,.9)
plt.title('6000')

plt.subplot(247)
plt.yticks([])
plt.pcolor(plts_09NEW)
plt.clim(.1,.9)
plt.title('9000')
#plt.colorbar()

plt.subplot(248)
plt.yticks([])
plt.pcolor(plts_10NEW)
plt.clim(.1,.9)
plt.title('10000')
plt.colorbar()

plt.subplots_adjust(wspace=0)
#plt.show()

plt.savefig('m64_serial.png')

# %%
gs=gridspec.GridSpec(2,2)

fig=plt.figure()
ax1=fig.add_subplot(gs[0,0])
ax1.pcolor(plts_01NEW)

ax2=fig.add_subplot(gs[0,1])
ax2.pcolor(plts_03NEW)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-093b4ba03216> in <module>()
#       4 ax1=fig.add_subplot(gs[0,0])
#       5 ax1.pcolor(plts_01NEW)
# ----> 6 ax1.colorbar()
#       7
#       8 ax2=fig.add_subplot(gs[0,1])
#
# AttributeError: 'AxesSubplot' object has no attribute 'colorbar'

# %%
np.mean(plts_08NEW)
# Out:
# 0.19221782842570934
